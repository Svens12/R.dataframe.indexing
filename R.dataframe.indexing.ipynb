# %%
id<-c(101,102,103)
name<-c('Bob','Alice','John')
marks<-c(78.25,59.45,63.85)
students<-data.frame(id,name,marks)

# %%
students
# Out:
#   id  name  marks
# 1 101 Bob   78.25
# 2 102 Alice 59.45
# 3 103 John  63.85

# %%
students[2,]
# Out:
#   id  name  marks
# 2 102 Alice 59.45

# %%
students[2:3,]
# Out:
#   id  name  marks
# 2 102 Alice 59.45
# 3 103 John  63.85

# %%
students[,1]
# Out:
# [1] 101 102 103

# %%
students[2:3,1:2]
# Out:
#   id  name
# 2 102 Alice
# 3 103 John

# %%
students[-2,-3]
# Out:
#   id  name
# 1 101 Bob
# 3 103 John

# %%
students[2]
# Out:
#   name
# 1 Bob
# 2 Alice
# 3 John

# %%
students[c(1,3),c(2:3)]
# Out:
#   name marks
# 1 Bob  78.25
# 3 John 63.85

# %%
students[[3]][1]
# Out:
# [1] 78.25

# %%
students$marks
# Out:
# [1] 78.25 59.45 63.85

# %%
students$marks[3]
# Out:
# [1] 63.85

# %%
students[[3]][2]<-24.00

# %%
students
# Out:
#   id  name  marks
# 1 101 Bob   78.25
# 2 102 Alice 24.00
# 3 103 John  63.85
